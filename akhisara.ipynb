# %% [markdown]
# <a href="https://colab.research.google.com/github/AkhiAmirulSara/akhiamirulsara/blob/main/akhisara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
p=math.pi
r=float(input("r="))
area=p*r*r
print("area=",area);
# Out:
# r=1.1
# area= 3.8013271108436504
